# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

df = pd.read_csv('Employee-Attrition.csv')
#df = sns.load_dataset('Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# <h2>Choose one variable and plot that variable four different ways.</h2>

# %%
sns.distplot(df.Age);
print('The distribution of Age variable with a density curve')
# Out:
# The distribution of Age variable

# %%
print('Histogram with a rug at each observation')
sns.distplot(df.Age, kde=False, rug='True')
plt.show()
# Out:
# Histogram with a rug at each observation

# %%
print('Box plot showing the range of age observation')
sns.boxplot(df.Age)
plt.show()
# Out:
# Box plot showing the range of age observation

# %%
sns.violinplot(x=df.Age)
plt.show()

# %% [markdown]
# <h2>Choose two continuous variables, and plot them three different ways.</h2>

# %%
sns.jointplot(x=df.TotalWorkingYears, y=df.MonthlyIncome)
sns.set_style('whitegrid')
print('Monthly income is positively correlated with experience')
plt.show()
# Out:
# Monthly income is positively correlated with experience

# %%
sns.jointplot(x=df.TotalWorkingYears, y=df.MonthlyIncome, data=df, kind="kde");
sns.set_style('whitegrid')
print('Most values cluster at the third quadrant, most workers have just less than ten years experience and earn around 5000 per month')
plt.show()
# Out:
# Most values cluster at the third quadrant, most workers have just less than ten years experience and earn around 5000 per month

# %%
sns.jointplot(x=df.TotalWorkingYears, y=df.MonthlyIncome, kind='hex', color='k')
sns.set_style('white')
plt.show()

# %% [markdown]
# <h3>Choose one continuous variable and one categorical variable, and plot them six different ways.</h3>

# %%
df2 = pd.read_csv('Death_rates_and_life_expectancy_at_birth.csv', index_col=0) #load new data set

# %%
df2.isnull().values.any() #Check for missing values
# Out:
# True

# %%
df2.dropna(inplace=True)

# %%
df2.isnull().values.any() #Check for missing values
# Out:
# False

# %%
df2.shape
# Out:
# (1035, 5)

# %%
df2.head(10)
# Out:
#    Year       Race         Sex  Average Life Expectancy (Years)  \
# 0  2015  All Races  Both Sexes                              NaN
# 1  2014  All Races  Both Sexes                             78.9
# 2  2013  All Races  Both Sexes                             78.8
# 3  2012  All Races  Both Sexes                             78.8
# 4  2011  All Races  Both Sexes                             78.7
# 5  2010  All Races  Both Sexes                             78.7
# 6  2009  All Races  Both Sexes                             78.5
# 7  2008  All Races  Both Sexes                             78.2
# 8  2007  All Races  Both Sexes                             78.1
# 9  2006  All Races  Both Sexes                             77.8
#
#    Age-adjusted Death Rate
# 0                    733.1
# 1                    724.6
# 2                    731.9
# 3                    732.8
# 4                    741.3
# 5                    747.0
# 6                    749.6
# 7                    774.9
# ...

# %%
g = sns.factorplot(x='Sex', y='Average Life Expectancy (Years)'
                   , data=df2, size=6, kind='bar')

# %%
g = sns.factorplot(x='Sex', y='Average Life Expectancy (Years)'
                   , data=df2, size=6, kind='point', join=False)

# %%
ax = sns.boxplot(x='Sex', y='Average Life Expectancy (Years)',
                 data=df2, palette='PRGn')

# %%
sns.violinplot(x='Sex', y='Average Life Expectancy (Years)', data=df2);

# %%
sns.swarmplot(y='Sex', x='Average Life Expectancy (Years)',
              data=df2);

# %%
sns.set(rc={'figure.figsize':(10, 5)})
sns.violinplot(y='Sex', x='Average Life Expectancy (Years)', 
               data=df2, inner=None)
sns.swarmplot(y='Sex', x='Average Life Expectancy (Years)',
              data=df2, color='w', alpha=.5);

#observation and summary of distribution
